# %% [markdown]
# # Get problem texts from Topcoder

# %%
import requests
import bs4
from bs4 import BeautifulSoup
import re
import psycopg2
import pandas as pd

# %% [markdown]
# ## Functions

# %% [markdown]
# ### url request

# %% [markdown]
# #### list of all contests

# %%
#url = "https://www.topcoder.com/tc?module=ProblemArchive&sr=0&er=5000&sc=&sd=&class=&cat=&div1l=&div2l=&mind1s=&mind2s=&maxd1s=&maxd2s=&wr="
#r = requests.get(url)
#with open('TC_questions_list.txt', 'w') as f:
#    f.write(r.content)
#len(r.content)

# %%
with open('TC_questions_list.txt') as f:
    r = f.readlines()
r = ''.join(r)

len(r)

# %%
soup = BeautifulSoup(r.content, 'html.parser')

soup_problems = soup.findAll('table', {'class': 'paddingTable2'})

tr = soup_problems[1].findAll('tr')
problem_list = []

cnt = 0
for t in tr:
#    print t.contents
    td = t.findAll('td')
    row = []
    links = []
    for d in td:
        a = d.find_all('a')
        links.extend(a)
        
        txt = d.text.encode('ascii', 'ignore').strip()
        txt = re.sub('\n[ ]+', ' ', txt)
        txt = re.sub('\. ', '_', txt)
        txt = re.sub(' ', '_', txt)
        txt = re.sub('%', '', txt)
        txt = txt.lower()
        row.append(txt)
    
    href = []
    if len(links) == 4:
        for a in links:
            # problem, round, memberprofile, detail
            href.append(a.attrs['href'])
    
    row.extend(href)
    
    if len(row) == 12:
        row.extend([
            'href_problem',
            'href_round',
            'href_writer',
            'href_detail'
        ])
        
    if len(row) != 16:
        continue
        
    
    problem_list.append(row)
        
#    cnt += 1
#    if cnt > 5:
#        break

# %%
df_list = pd.DataFrame.from_dict(problem_list[1:])
problem_list[0][0] = 0
problem_list[0][10] = 10
problem_list[0][11] = 11
df_list.columns = problem_list[0]
df_list.drop([0, 10, 11], axis=1, inplace=True)

# %% [markdown]
# #### get problem details

# %%
base_url = "https://www.topcoder.com/"

df_list.head()
# Out:
#         problemname challenge        date  writer  \
# 0     classictowers   srm_715  05.30.2017  lg5293
# 1  imagecompression   srm_715  05.30.2017  lg5293
# 2         inprepost   srm_715  05.30.2017  lg5293
# 3      maximumrange   srm_715  05.30.2017  lg5293
# 4  maximumrangediv2   srm_715  05.30.2017  lg5293
#
#                          categories div_1level div_1success_rate div_2level  \
# 0               dynamic_programming          2             68.97
# 1               string_manipulation                                       1
# 2                            greedy                                       3
# 3                            greedy          1             97.97
# 4  brute_force,_string_manipulation                                       2
#
#   div_2success_rate                        href_problem  \
# 0                    /stat?c=problem_statement&pm=14591
# 1             77.60  /stat?c=problem_statement&pm=14612
# 2             31.43  /stat?c=problem_statement&pm=14610
# 3                    /stat?c=problem_statement&pm=14613
# 4             84.43  /stat?c=problem_statement&pm=14611
#
#                         href_round  \
# 0  /stat?c=round_overview&rd=16884
# 1  /stat?c=round_overview&rd=16884
# 2  /stat?c=round_overview&rd=16884
# 3  /stat?c=round_overview&rd=16884
# 4  /stat?c=round_overview&rd=16884
#
#                                     href_writer  \
# 0  /tc?module=MemberProfile&cr=22858920&tab=alg
# 1  /tc?module=MemberProfile&cr=22858920&tab=alg
# 2  /tc?module=MemberProfile&cr=22858920&tab=alg
# 3  /tc?module=MemberProfile&cr=22858920&tab=alg
# 4  /tc?module=MemberProfile&cr=22858920&tab=alg
#
#                                   href_detail
# 0  /tc?module=ProblemDetail&rd=16884&pm=14591
# 1  /tc?module=ProblemDetail&rd=16884&pm=14612
# 2  /tc?module=ProblemDetail&rd=16884&pm=14610
# 3  /tc?module=ProblemDetail&rd=16884&pm=14613
# 4  /tc?module=ProblemDetail&rd=16884&pm=14611

# %%
#from time import sleep
#def getproblemtext(contest, problem):
#    maxtries = 5
#    tries = 0
#    url = 'http://codeforces.com/problemset/problem/' + str(contest) + '/' + str(problem)
#    print url
#    
#    while tries < maxtries:
#        try:
#            r = requests.get(url)
#            return r.content
#        except:
#            tries += 1
#            sleep(5)
#    print "ERROR GETTING CONTEST INFO FOR", contest, problem_data.csv

# %% [markdown]
# ### scientific notation -> 0's

# %%
# turn scientific notation into 0s
def sci2num(txt):
    #txt = txt.encode('utf-8')
    exponents = map(int, re.findall('10<sup class="upper-index">(.)</sup>', txt))
    for e in exponents:
        estr = '10' + ''.join(map(str, [0]*(e-1)))
        txt = re.sub('10<sup class="upper-index">' + str(e) + '</sup>', estr, txt)
    #return BeautifulSoup(txt, 'html.parser')
    return txt

# %% [markdown]
# ### Ignore first tag

# %%
def ignore1sttag(bs4obj):
    inputlist = []
    for cont in bs4obj.contents:
        if type(cont) == bs4.NavigableString:
            inputlist.append(cont)
        elif len(cont.attrs) == 0:
            inputlist.append(cont.text)
    out = ''.join(inputlist)
    return out

# %% [markdown]
# ### parsing

# %%
def get_problem_dict(contestid, problemid):
    r = getproblemtext(contestid, problemid)
    r = sci2num(r)

    soup = BeautifulSoup(r, 'html.parser')
    #print(soup.prettify())

    statement = soup.find("div", { "class" : "problem-statement" })
    problem_name = soup.find("div", { "class" : "title" }).string

    tmp = soup.find("div", { "class" : "time-limit" })
    timelimit = tmp.contents[-1]
    timelimit = timelimit.split(' ')[0]
    timelimit = float(timelimit)

    tmp = soup.find("div", { "class" : "memory-limit" })
    memlimit = tmp.contents[-1]
    memlimit = memlimit.split(' ')[0]
    memlimit = int(memlimit)

    children = []
    for c in statement.children:
        children.append(c)

    description = children[1]
    assert(len(description.attrs) == 0)
    txt_descr = description.text

    txt_input = ignore1sttag(children[2])
        
    txt_output = ignore1sttag(children[3])
    
    if (len(children) >= 6):
        txt_note = ignore1sttag(children[5])
    else:
        txt_note = ''

    assert(children[4].attrs['class'][0] == u'sample-tests')

    #print problem_name, '\n'
    #print timelimit, '\n'
    #print memlimit, '\n'
    #print txt_descr, '\n'
    #print txt_input, '\n'
    #print txt_output, '\n'
    #print txt_note, '\n'

    problem_dict = {
        'contestid':     contestid,
        'problemid':     problemid,
        'problemname':   problem_name,
        'timelimit' :    timelimit,
        'memlimit' :     memlimit,
        'txt_descr' :    txt_descr,
        'txt_input' :    txt_input,
        'txt_output':    txt_output,
        'txt_note':      txt_note
    }

    return problem_dict

# %% [markdown]
# ## Calling functions

# %%
db = 'codeforces'
usr = 'Joy'
con = psycopg2.connect(database = db, user = usr)
cur = con.cursor()

# %%
query = """
SELECT contestid, problemid FROM problem_info;
"""
cur.execute(query)
cid_pid = cur.fetchall()
#df_cid_pid = pd.read_sql(query, con)

# %% [markdown]
# ### number of problems in database
# * total: 4,248
# * have some tags: 3,021

# %%
df_cid_pid.shape
# Out:
# (4248, 2)

# %%
con.rollback()

query = """
SELECT COUNT(*) FROM (SELECT DISTINCT contestid, problemid FROM tags) AS temp;
"""
cur.execute(query)
cur.fetchall()[0][0]
# Out:
# 3021L

# %% [markdown]
# ### get question texts from CF

# %%
import os.path

# %%
txtlist = []
idx = 0
last_idx = 48

out_file = 'problem_texts.tsv'

for cid, pid in cid_pid[last_idx:]:
    print last_idx + idx
    txtlist.append(get_problem_dict(cid, pid))
    
    if idx%5==0:
        df_out = pd.DataFrame.from_dict(txtlist)
        if (os.path.exists(out_file)):
            df_out.to_csv(out_file, sep='\t', header=False, index=False, encoding='utf-8', mode='a')
        else:
            df_out.to_csv(out_file, sep='\t', header=True, index=False, encoding='utf-8', mode='w')
        txtlist = []
        print "------------------------- written to file", out_file
        
    idx+=1;
#get_problem_dict(contestid, problemid)
# Out:
# 48
# http://codeforces.com/problemset/problem/13/E
#  Type
#  means that it is required to set the power of hole
#  to
# , and type
#  means that it is required to throw a ball into the
# -th hole. Numbers
#  and
#  are positive integers do not exceeding
# .
# ------------------------- written to file problem_texts.tsv
# 49
# http://codeforces.com/problemset/problem/14/A
# 50
# http://codeforces.com/problemset/problem/14/B
# 51
# http://codeforces.com/problemset/problem/14/C
# 52
# http://codeforces.com/problemset/problem/14/D
# 53
# http://codeforces.com/problemset/problem/14/E
# ------------------------- written to file problem_texts.tsv
# 54
# http://codeforces.com/problemset/problem/16/A
# 55
# http://codeforces.com/problemset/problem/16/B
# 56
# http://codeforces.com/problemset/problem/16/C
# 57
# http://codeforces.com/problemset/problem/16/D
#  The problem authors recommend you to look through these descriptions before you start with the problem.
# 58
# http://codeforces.com/problemset/problem/16/E
# ------------------------- written to file problem_texts.tsv
# 59
# http://codeforces.com/problemset/problem/17/A
# 60
# http://codeforces.com/problemset/problem/17/B
# 61
# http://codeforces.com/problemset/problem/17/C
# 62
# http://codeforces.com/problemset/problem/17/D
# 63
# http://codeforces.com/problemset/problem/17/E
# ------------------------- written to file problem_texts.tsv
# 64
# http://codeforces.com/problemset/problem/18/A
# 65
# http://codeforces.com/problemset/problem/18/B
# 66
# http://codeforces.com/problemset/problem/18/C
# 67
# http://codeforces.com/problemset/problem/18/D
# 68
# http://codeforces.com/problemset/problem/18/E
# ------------------------- written to file problem_texts.tsv
# 69
# http://codeforces.com/problemset/problem/19/A
# 70
# http://codeforces.com/problemset/problem/19/B
# 71
# http://codeforces.com/problemset/problem/19/C
# 72
# http://codeforces.com/problemset/problem/19/D
# 73
# http://codeforces.com/problemset/problem/19/E
# ------------------------- written to file problem_texts.tsv
# 74
# http://codeforces.com/problemset/problem/22/A
# 75
# http://codeforces.com/problemset/problem/22/B
# 76
# http://codeforces.com/problemset/problem/22/C
# 77
# http://codeforces.com/problemset/problem/22/D
# 78
# http://codeforces.com/problemset/problem/22/E
# ------------------------- written to file problem_texts.tsv
# 79
# http://codeforces.com/problemset/problem/23/A
# 80
# http://codeforces.com/problemset/problem/23/B
# 81
# http://codeforces.com/problemset/problem/23/C
# 82
# http://codeforces.com/problemset/problem/23/D
# 83
# http://codeforces.com/problemset/problem/23/E
# ------------------------- written to file problem_texts.tsv
# 84
# http://codeforces.com/problemset/problem/24/A
# 85
# http://codeforces.com/problemset/problem/24/B
# 86
# http://codeforces.com/problemset/problem/24/C
# 87
# http://codeforces.com/problemset/problem/24/D
# 88
# http://codeforces.com/problemset/problem/24/E
# ------------------------- written to file problem_texts.tsv
# 89
# http://codeforces.com/problemset/problem/25/A
# 90
# http://codeforces.com/problemset/problem/25/B
# 91
# http://codeforces.com/problemset/problem/25/C
# 92
# http://codeforces.com/problemset/problem/25/D
# 93
# http://codeforces.com/problemset/problem/25/E
# ------------------------- written to file problem_texts.tsv
# 94
# http://codeforces.com/problemset/problem/26/A
# 95
# http://codeforces.com/problemset/problem/26/B
# 96
# http://codeforces.com/problemset/problem/26/C
# 97
# http://codeforces.com/problemset/problem/26/D
# 98
# http://codeforces.com/problemset/problem/26/E
# ------------------------- written to file problem_texts.tsv
# 99
# http://codeforces.com/problemset/problem/27/A
# 100
# http://codeforces.com/problemset/problem/27/B
# 101
# http://codeforces.com/problemset/problem/27/C
# 102
# http://codeforces.com/problemset/problem/27/D
# 103
# http://codeforces.com/problemset/problem/27/E
# ------------------------- written to file problem_texts.tsv
# 104
# http://codeforces.com/problemset/problem/28/A
# 105
# http://codeforces.com/problemset/problem/28/B
# 106
# http://codeforces.com/problemset/problem/28/C
# 107
# http://codeforces.com/problemset/problem/28/D
# 108
# http://codeforces.com/problemset/problem/28/E
# ------------------------- written to file problem_texts.tsv
# 109
# http://codeforces.com/problemset/problem/29/A
# 110
# http://codeforces.com/problemset/problem/29/B
# 111
# http://codeforces.com/problemset/problem/29/C
# 112
# http://codeforces.com/problemset/problem/29/D
# 113
# http://codeforces.com/problemset/problem/29/E
# ------------------------- written to file problem_texts.tsv
# 114
# http://codeforces.com/problemset/problem/30/A
# 115
# http://codeforces.com/problemset/problem/30/B
# 116
# http://codeforces.com/problemset/problem/30/C
# 117
# http://codeforces.com/problemset/problem/30/D
# 118
# http://codeforces.com/problemset/problem/30/E
# ------------------------- written to file problem_texts.tsv
# 119
# http://codeforces.com/problemset/problem/31/A
# 120
# http://codeforces.com/problemset/problem/31/B
# 121
# http://codeforces.com/problemset/problem/31/C
# 122
# http://codeforces.com/problemset/problem/31/D
# 123
# http://codeforces.com/problemset/problem/31/E
# ------------------------- written to file problem_texts.tsv
# 124
# http://codeforces.com/problemset/problem/32/A
# 125
# http://codeforces.com/problemset/problem/32/B
# 126
# http://codeforces.com/problemset/problem/32/C
# 127
# http://codeforces.com/problemset/problem/32/D
# 128
# http://codeforces.com/problemset/problem/32/E
# ------------------------- written to file problem_texts.tsv
# 129
# http://codeforces.com/problemset/problem/33/A
# 130
# http://codeforces.com/problemset/problem/33/B
# 131
# http://codeforces.com/problemset/problem/33/C
# 132
# http://codeforces.com/problemset/problem/33/D
# 133
# http://codeforces.com/problemset/problem/33/E
# ------------------------- written to file problem_texts.tsv
# 134
# http://codeforces.com/problemset/problem/34/A
# 135
# http://codeforces.com/problemset/problem/34/B
# 136
# http://codeforces.com/problemset/problem/34/C
# 137
# http://codeforces.com/problemset/problem/34/D
# 138
# http://codeforces.com/problemset/problem/34/E
# ------------------------- written to file problem_texts.tsv
# 139
# http://codeforces.com/problemset/problem/35/A
# 140
# http://codeforces.com/problemset/problem/35/B
# 141
# http://codeforces.com/problemset/problem/35/C
# 142
# http://codeforces.com/problemset/problem/35/D
# 143
# http://codeforces.com/problemset/problem/35/E
# ------------------------- written to file problem_texts.tsv
# 144
# http://codeforces.com/problemset/problem/36/A
# 145
# http://codeforces.com/problemset/problem/36/B
# 146
# http://codeforces.com/problemset/problem/36/C
# 147
# http://codeforces.com/problemset/problem/36/D
# 148
# http://codeforces.com/problemset/problem/36/E
# ------------------------- written to file problem_texts.tsv
# 149
# http://codeforces.com/problemset/problem/37/A
# 150
# http://codeforces.com/problemset/problem/37/B
# 151
# http://codeforces.com/problemset/problem/37/C
# 152
# http://codeforces.com/problemset/problem/37/D
# 153
# http://codeforces.com/problemset/problem/37/E
# ------------------------- written to file problem_texts.tsv
# 154
# http://codeforces.com/problemset/problem/38/A
# 155
# http://codeforces.com/problemset/problem/38/B
# 156
# http://codeforces.com/problemset/problem/38/C
# 157
# http://codeforces.com/problemset/problem/38/D
# 158
# http://codeforces.com/problemset/problem/38/E
# ------------------------- written to file problem_texts.tsv
# 159
# http://codeforces.com/problemset/problem/38/F
# 160
# http://codeforces.com/problemset/problem/38/G
# 161
# http://codeforces.com/problemset/problem/38/H
# 162
# http://codeforces.com/problemset/problem/40/A
# 163
# http://codeforces.com/problemset/problem/40/B
# ------------------------- written to file problem_texts.tsv
# 164
# http://codeforces.com/problemset/problem/40/C
# 165
# http://codeforces.com/problemset/problem/40/D
# 166
# http://codeforces.com/problemset/problem/40/E
# 167
# http://codeforces.com/problemset/problem/41/A
# 168
# http://codeforces.com/problemset/problem/41/B
# ------------------------- written to file problem_texts.tsv
# 169
# http://codeforces.com/problemset/problem/41/C
# 170
# http://codeforces.com/problemset/problem/41/D
# 171
# http://codeforces.com/problemset/problem/41/E
# 172
# http://codeforces.com/problemset/problem/42/A
# 173
# http://codeforces.com/problemset/problem/42/B
# ------------------------- written to file problem_texts.tsv
# 174
# http://codeforces.com/problemset/problem/42/C
# 175
# http://codeforces.com/problemset/problem/42/D
# 176
# http://codeforces.com/problemset/problem/42/E
# 177
# http://codeforces.com/problemset/problem/43/A
# 178
# http://codeforces.com/problemset/problem/43/B
# ------------------------- written to file problem_texts.tsv
# 179
# http://codeforces.com/problemset/problem/43/C
# 180
# http://codeforces.com/problemset/problem/43/D
# 181
# http://codeforces.com/problemset/problem/43/E
# 182
# http://codeforces.com/problemset/problem/46/A
# 183
# http://codeforces.com/problemset/problem/46/B
# ------------------------- written to file problem_texts.tsv
# 184
# http://codeforces.com/problemset/problem/46/C
# 185
# http://codeforces.com/problemset/problem/46/D
# 186
# http://codeforces.com/problemset/problem/46/E
# 187
# http://codeforces.com/problemset/problem/46/F
# 188
# http://codeforces.com/problemset/problem/46/G
# ------------------------- written to file problem_texts.tsv
# 189
# http://codeforces.com/problemset/problem/47/A
# 190
# http://codeforces.com/problemset/problem/47/B
# 191
# http://codeforces.com/problemset/problem/47/C
# 192
# http://codeforces.com/problemset/problem/47/D
# 193
# http://codeforces.com/problemset/problem/47/E
# ------------------------- written to file problem_texts.tsv
# 194
# http://codeforces.com/problemset/problem/48/A
# 195
# http://codeforces.com/problemset/problem/48/B
# 196
# http://codeforces.com/problemset/problem/48/C
# 197
# http://codeforces.com/problemset/problem/48/D
# 198
# http://codeforces.com/problemset/problem/48/E
# ------------------------- written to file problem_texts.tsv
# 199
# http://codeforces.com/problemset/problem/48/F
# 200
# http://codeforces.com/problemset/problem/48/G
# 201
# http://codeforces.com/problemset/problem/48/H
#  If multiple solutions exist, output any.
# 202
# http://codeforces.com/problemset/problem/49/A
# 203
# http://codeforces.com/problemset/problem/49/B
# ------------------------- written to file problem_texts.tsv
# 204
# http://codeforces.com/problemset/problem/49/C
# 205
# http://codeforces.com/problemset/problem/49/D
# 206
# http://codeforces.com/problemset/problem/49/E
# 207
# http://codeforces.com/problemset/problem/51/A
# 208
# http://codeforces.com/problemset/problem/51/B
# ------------------------- written to file problem_texts.tsv
# 209
# http://codeforces.com/problemset/problem/51/C
# 210
# http://codeforces.com/problemset/problem/51/D
# 211
# http://codeforces.com/problemset/problem/51/E
# 212
# http://codeforces.com/problemset/problem/51/F
# 213
# http://codeforces.com/problemset/problem/53/A
# ------------------------- written to file problem_texts.tsv
# 214
# http://codeforces.com/problemset/problem/53/B
# 215
# http://codeforces.com/problemset/problem/53/C
# 216
# http://codeforces.com/problemset/problem/53/D
# 217
# http://codeforces.com/problemset/problem/53/E
# 218
# http://codeforces.com/problemset/problem/54/A
# ------------------------- written to file problem_texts.tsv
# 219
# http://codeforces.com/problemset/problem/54/B
# 220
# http://codeforces.com/problemset/problem/54/C
# 221
# http://codeforces.com/problemset/problem/54/D
# 222
# http://codeforces.com/problemset/problem/54/E
# 223
# http://codeforces.com/problemset/problem/55/A
# ------------------------- written to file problem_texts.tsv
# 224
# http://codeforces.com/problemset/problem/55/B
# 225
# http://codeforces.com/problemset/problem/55/C
# 226
# http://codeforces.com/problemset/problem/55/D
# 227
# http://codeforces.com/problemset/problem/55/E
# 228
# http://codeforces.com/problemset/problem/56/A
# ------------------------- written to file problem_texts.tsv
# 229
# http://codeforces.com/problemset/problem/56/B
# 230
# http://codeforces.com/problemset/problem/56/C
# 231
# http://codeforces.com/problemset/problem/56/D
# 232
# http://codeforces.com/problemset/problem/56/E
# 233
# http://codeforces.com/problemset/problem/57/A
# ------------------------- written to file problem_texts.tsv
# 234
# http://codeforces.com/problemset/problem/57/B
# 235
# http://codeforces.com/problemset/problem/57/C
# 236
# http://codeforces.com/problemset/problem/57/D
# 237
# http://codeforces.com/problemset/problem/57/E
# 238
# http://codeforces.com/problemset/problem/58/A
# ------------------------- written to file problem_texts.tsv
# 239
# http://codeforces.com/problemset/problem/58/B
# 240
# http://codeforces.com/problemset/problem/58/C
# 241
# http://codeforces.com/problemset/problem/58/D
# 242
# http://codeforces.com/problemset/problem/58/E
# 243
# http://codeforces.com/problemset/problem/59/A
# ------------------------- written to file problem_texts.tsv
# 244
# http://codeforces.com/problemset/problem/59/B
# 245
# http://codeforces.com/problemset/problem/59/C
# 246
# http://codeforces.com/problemset/problem/59/D
# 247
# http://codeforces.com/problemset/problem/59/E
# 248
# http://codeforces.com/problemset/problem/60/A
# ------------------------- written to file problem_texts.tsv
# 249
# http://codeforces.com/problemset/problem/60/B
# 250
# http://codeforces.com/problemset/problem/60/C
# 251
# http://codeforces.com/problemset/problem/60/D
# 252
# http://codeforces.com/problemset/problem/60/E
# 253
# http://codeforces.com/problemset/problem/61/A
# ------------------------- written to file problem_texts.tsv
# 254
# http://codeforces.com/problemset/problem/61/B
# 255
# http://codeforces.com/problemset/problem/61/C
# 256
# http://codeforces.com/problemset/problem/61/D
# 257
# http://codeforces.com/problemset/problem/61/E
# 258
# http://codeforces.com/problemset/problem/62/A
# ------------------------- written to file problem_texts.tsv
# 259
# http://codeforces.com/problemset/problem/62/B
# 260
# http://codeforces.com/problemset/problem/62/C
# 261
# http://codeforces.com/problemset/problem/62/D
# 262
# http://codeforces.com/problemset/problem/62/E
# 263
# http://codeforces.com/problemset/problem/63/A
# ------------------------- written to file problem_texts.tsv
# 264
# http://codeforces.com/problemset/problem/63/B
# 265
# http://codeforces.com/problemset/problem/63/C
# 266
# http://codeforces.com/problemset/problem/63/D
# 267
# http://codeforces.com/problemset/problem/63/E
# 268
# http://codeforces.com/problemset/problem/65/A
# ------------------------- written to file problem_texts.tsv
# 269
# http://codeforces.com/problemset/problem/65/B
# 270
# http://codeforces.com/problemset/problem/65/C
# 271
# http://codeforces.com/problemset/problem/65/D
# 272
# http://codeforces.com/problemset/problem/65/E
# 273
# http://codeforces.com/problemset/problem/66/A
# ------------------------- written to file problem_texts.tsv
# 274
# http://codeforces.com/problemset/problem/66/B
# 275
# http://codeforces.com/problemset/problem/66/C
# 276
# http://codeforces.com/problemset/problem/66/D
# 277
# http://codeforces.com/problemset/problem/66/E
# 278
# http://codeforces.com/problemset/problem/67/A
# ------------------------- written to file problem_texts.tsv
# 279
# http://codeforces.com/problemset/problem/67/B
# 280
# http://codeforces.com/problemset/problem/67/C
# 281
# http://codeforces.com/problemset/problem/67/D
# 282
# http://codeforces.com/problemset/problem/67/E
# 283
# http://codeforces.com/problemset/problem/68/A
# ------------------------- written to file problem_texts.tsv
# 284
# http://codeforces.com/problemset/problem/68/B
# 285
# http://codeforces.com/problemset/problem/68/C
# 286
# http://codeforces.com/problemset/problem/68/D
# 287
# http://codeforces.com/problemset/problem/68/E
# 288
# http://codeforces.com/problemset/problem/69/A
# ------------------------- written to file problem_texts.tsv
# 289
# http://codeforces.com/problemset/problem/69/B
# 290
# http://codeforces.com/problemset/problem/69/C
# 291
# http://codeforces.com/problemset/problem/69/D
# 292
# http://codeforces.com/problemset/problem/69/E
# 293
# http://codeforces.com/problemset/problem/70/A
# ------------------------- written to file problem_texts.tsv
# 294
# http://codeforces.com/problemset/problem/70/B
# 295
# http://codeforces.com/problemset/problem/70/C
# 296
# http://codeforces.com/problemset/problem/70/D
# 297
# http://codeforces.com/problemset/problem/70/E
# 298
# http://codeforces.com/problemset/problem/71/A
# ------------------------- written to file problem_texts.tsv
# 299
# http://codeforces.com/problemset/problem/71/B
# 300
# http://codeforces.com/problemset/problem/71/C
# 301
# http://codeforces.com/problemset/problem/71/D
# 302
# http://codeforces.com/problemset/problem/71/E
# 303
# http://codeforces.com/problemset/problem/73/A
# ------------------------- written to file problem_texts.tsv
# 304
# http://codeforces.com/problemset/problem/73/B
# 305
# http://codeforces.com/problemset/problem/73/C
# 306
# http://codeforces.com/problemset/problem/73/D
# 307
# http://codeforces.com/problemset/problem/73/E
# 308
# http://codeforces.com/problemset/problem/73/F
# ------------------------- written to file problem_texts.tsv
# 309
# http://codeforces.com/problemset/problem/74/A
# 310
# http://codeforces.com/problemset/problem/74/B
# 311
# http://codeforces.com/problemset/problem/74/C
# 312
# http://codeforces.com/problemset/problem/74/D
# 313
# http://codeforces.com/problemset/problem/74/E
# ------------------------- written to file problem_texts.tsv
# 314
# http://codeforces.com/problemset/problem/75/A
# 315
# http://codeforces.com/problemset/problem/75/B
# 316
# http://codeforces.com/problemset/problem/75/C
# 317
# http://codeforces.com/problemset/problem/75/D
# 318
# http://codeforces.com/problemset/problem/75/E
# ------------------------- written to file problem_texts.tsv
# 319
# http://codeforces.com/problemset/problem/77/A
# 320
# http://codeforces.com/problemset/problem/77/B
# 321
# http://codeforces.com/problemset/problem/77/C
# 322
# http://codeforces.com/problemset/problem/77/D
# 323
# http://codeforces.com/problemset/problem/77/E
# ------------------------- written to file problem_texts.tsv
# 324
# http://codeforces.com/problemset/problem/78/A
# 325
# http://codeforces.com/problemset/problem/78/B
# 326
# http://codeforces.com/problemset/problem/78/C
# 327
# http://codeforces.com/problemset/problem/78/D
# 328
# http://codeforces.com/problemset/problem/78/E
# ------------------------- written to file problem_texts.tsv
# 329
# http://codeforces.com/problemset/problem/79/A
# 330
# http://codeforces.com/problemset/problem/79/B
# 331
# http://codeforces.com/problemset/problem/79/C
# 332
# http://codeforces.com/problemset/problem/79/D
# 333
# http://codeforces.com/problemset/problem/79/E
#  Here, a red point represents a point that contains a sensor.
# ------------------------- written to file problem_texts.tsv
# 334
# http://codeforces.com/problemset/problem/80/A
# 335
# http://codeforces.com/problemset/problem/80/B
# 336
# http://codeforces.com/problemset/problem/80/C
# 337
# http://codeforces.com/problemset/problem/80/D
# 338
# http://codeforces.com/problemset/problem/80/E
# ------------------------- written to file problem_texts.tsv
# 339
# http://codeforces.com/problemset/problem/81/A
# 340
# http://codeforces.com/problemset/problem/81/B
# 341
# http://codeforces.com/problemset/problem/81/C
# 342
# http://codeforces.com/problemset/problem/81/D
# 343
# http://codeforces.com/problemset/problem/81/E
# ------------------------- written to file problem_texts.tsv
# 344
# http://codeforces.com/problemset/problem/82/A
# 345
# http://codeforces.com/problemset/problem/82/B
# 346
# http://codeforces.com/problemset/problem/137/C
# 347
# http://codeforces.com/problemset/problem/82/C
# 348
# http://codeforces.com/problemset/problem/82/D
# ------------------------- written to file problem_texts.tsv
# 349
# http://codeforces.com/problemset/problem/82/E
# 350
# http://codeforces.com/problemset/problem/83/A
# 351
# http://codeforces.com/problemset/problem/83/B
# 352
# http://codeforces.com/problemset/problem/83/C
# 353
# http://codeforces.com/problemset/problem/83/D
# ------------------------- written to file problem_texts.tsv
# 354
# http://codeforces.com/problemset/problem/83/E
# 355
# http://codeforces.com/problemset/problem/84/A
# 356
# http://codeforces.com/problemset/problem/84/B
# 357
# http://codeforces.com/problemset/problem/84/C
# 358
# http://codeforces.com/problemset/problem/84/D
# ------------------------- written to file problem_texts.tsv
# 359
# http://codeforces.com/problemset/problem/84/E
# 360
# http://codeforces.com/problemset/problem/85/A
# 361
# http://codeforces.com/problemset/problem/85/B
# 362
# http://codeforces.com/problemset/problem/85/C
# 363
# http://codeforces.com/problemset/problem/85/D
# ------------------------- written to file problem_texts.tsv
# 364
# http://codeforces.com/problemset/problem/85/E
# 365
# http://codeforces.com/problemset/problem/86/A
# 366
# http://codeforces.com/problemset/problem/86/B
# 367
# http://codeforces.com/problemset/problem/86/C
# 368
# http://codeforces.com/problemset/problem/86/D
#  Then
# ,
# ,
# , so the power is equal to
# .
# ------------------------- written to file problem_texts.tsv
# 369
# http://codeforces.com/problemset/problem/86/E
# 370
# http://codeforces.com/problemset/problem/87/A
# 371
# http://codeforces.com/problemset/problem/87/B
# 372
# http://codeforces.com/problemset/problem/87/C
# 373
# http://codeforces.com/problemset/problem/87/D
# ------------------------- written to file problem_texts.tsv
# 374
# http://codeforces.com/problemset/problem/87/E
# 375
# http://codeforces.com/problemset/problem/88/A
# 376
# http://codeforces.com/problemset/problem/88/B
# 377
# http://codeforces.com/problemset/problem/88/C
# 378
# http://codeforces.com/problemset/problem/88/D
# ------------------------- written to file problem_texts.tsv
# 379
# http://codeforces.com/problemset/problem/88/E
# 380
# http://codeforces.com/problemset/problem/89/A
# 381
# http://codeforces.com/problemset/problem/89/B
#
# 382
# http://codeforces.com/problemset/problem/89/C
# 383
# http://codeforces.com/problemset/problem/89/D
# ------------------------- written to file problem_texts.tsv
# 384
# http://codeforces.com/problemset/problem/89/E
# 385
# http://codeforces.com/problemset/problem/90/A
# 386
# http://codeforces.com/problemset/problem/90/B
# 387
# http://codeforces.com/problemset/problem/90/C
# 388
# http://codeforces.com/problemset/problem/90/D
#
# ------------------------- written to file problem_texts.tsv
# 389
# http://codeforces.com/problemset/problem/90/E
# 390
# http://codeforces.com/problemset/problem/91/A
# 391
# http://codeforces.com/problemset/problem/91/B
# 392
# http://codeforces.com/problemset/problem/91/C
#
#
#
# 393
# http://codeforces.com/problemset/problem/91/D
# ------------------------- written to file problem_texts.tsv
# 394
# http://codeforces.com/problemset/problem/91/E
# 395
# http://codeforces.com/problemset/problem/92/A
# 396
# http://codeforces.com/problemset/problem/92/B
# 397
# http://codeforces.com/problemset/problem/92/C
# 398
# http://codeforces.com/problemset/problem/92/D
# ------------------------- written to file problem_texts.tsv
# 399
# http://codeforces.com/problemset/problem/92/E
#
#
#
# 400
# http://codeforces.com/problemset/problem/93/A
# 401
# http://codeforces.com/problemset/problem/93/B
# 402
# http://codeforces.com/problemset/problem/93/C
# 403
# http://codeforces.com/problemset/problem/93/D
# ------------------------- written to file problem_texts.tsv
# 404
# http://codeforces.com/problemset/problem/93/E
# 405
# http://codeforces.com/problemset/problem/94/A
# 406
# http://codeforces.com/problemset/problem/94/B
# 407
# http://codeforces.com/problemset/problem/94/C
# 408
# http://codeforces.com/problemset/problem/94/D
# ------------------------- written to file problem_texts.tsv
# 409
# http://codeforces.com/problemset/problem/94/E
# 410
# http://codeforces.com/problemset/problem/95/A
# 411
# http://codeforces.com/problemset/problem/95/B
# 412
# http://codeforces.com/problemset/problem/95/C
# 413
# http://codeforces.com/problemset/problem/95/D
# ------------------------- written to file problem_texts.tsv
# 414
# http://codeforces.com/problemset/problem/95/E
# 415
# http://codeforces.com/problemset/problem/96/A
# 416
# http://codeforces.com/problemset/problem/96/B
# 417
# http://codeforces.com/problemset/problem/96/C
# 418
# http://codeforces.com/problemset/problem/96/D
# ------------------------- written to file problem_texts.tsv
# 419
# http://codeforces.com/problemset/problem/96/E
# 420
# http://codeforces.com/problemset/problem/97/A
# 421
# http://codeforces.com/problemset/problem/97/B
# 422
# http://codeforces.com/problemset/problem/97/C
# 423
# http://codeforces.com/problemset/problem/97/D
# ------------------------- written to file problem_texts.tsv
# 424
# http://codeforces.com/problemset/problem/97/E
# 425
# http://codeforces.com/problemset/problem/101/A
# 426
# http://codeforces.com/problemset/problem/101/B
# 427
# http://codeforces.com/problemset/problem/101/C
# 428
# http://codeforces.com/problemset/problem/101/D
# ------------------------- written to file problem_texts.tsv
# 429
# http://codeforces.com/problemset/problem/101/E
# 430
# http://codeforces.com/problemset/problem/102/A
# 431
# http://codeforces.com/problemset/problem/102/B
# 432
# http://codeforces.com/problemset/problem/102/C
# 433
# http://codeforces.com/problemset/problem/102/D
# ------------------------- written to file problem_texts.tsv
# 434
# http://codeforces.com/problemset/problem/102/E
# 435
# http://codeforces.com/problemset/problem/103/A
# 436
# http://codeforces.com/problemset/problem/103/B
# 437
# http://codeforces.com/problemset/problem/103/C
# 438
# http://codeforces.com/problemset/problem/103/D
# ------------------------- written to file problem_texts.tsv
# 439
# http://codeforces.com/problemset/problem/103/E
# 440
# http://codeforces.com/problemset/problem/104/A
# 441
# http://codeforces.com/problemset/problem/104/B
# 442
# http://codeforces.com/problemset/problem/104/C
# 443
# http://codeforces.com/problemset/problem/104/D
# ------------------------- written to file problem_texts.tsv
# 444
# http://codeforces.com/problemset/problem/104/E
# 445
# http://codeforces.com/problemset/problem/105/A
# 446
# http://codeforces.com/problemset/problem/105/B
# 447
# http://codeforces.com/problemset/problem/105/C
# 448
# http://codeforces.com/problemset/problem/105/D
#  If your browser does not support APNG and you see just static image, you can see GIF version of this image by the following link:
# ------------------------- written to file problem_texts.tsv
# 449
# http://codeforces.com/problemset/problem/105/E
# 450
# http://codeforces.com/problemset/problem/106/A
# 451
# http://codeforces.com/problemset/problem/106/B
# 452
# http://codeforces.com/problemset/problem/106/C
# 453
# http://codeforces.com/problemset/problem/106/D
# ------------------------- written to file problem_texts.tsv
# 454
# http://codeforces.com/problemset/problem/106/E
# 455
# http://codeforces.com/problemset/problem/107/A
# 456
# http://codeforces.com/problemset/problem/107/B
# 457
# http://codeforces.com/problemset/problem/107/C
# 458
# http://codeforces.com/problemset/problem/107/D
# ------------------------- written to file problem_texts.tsv
# 459
# http://codeforces.com/problemset/problem/107/E
# 460
# http://codeforces.com/problemset/problem/109/A
# 461
# http://codeforces.com/problemset/problem/109/B
# 462
# http://codeforces.com/problemset/problem/109/C
# 463
# http://codeforces.com/problemset/problem/109/D
# ------------------------- written to file problem_texts.tsv
# 464
# http://codeforces.com/problemset/problem/109/E
# 465
# http://codeforces.com/problemset/problem/110/A
# 466
# http://codeforces.com/problemset/problem/110/B
# 467
# http://codeforces.com/problemset/problem/110/C
# 468
# http://codeforces.com/problemset/problem/110/D
# ------------------------- written to file problem_texts.tsv
# 469
# http://codeforces.com/problemset/problem/110/E
# 470
# http://codeforces.com/problemset/problem/111/A
# 471
# http://codeforces.com/problemset/problem/111/B
# 472
# http://codeforces.com/problemset/problem/111/C
# 473
# http://codeforces.com/problemset/problem/111/D
# ------------------------- written to file problem_texts.tsv
# 474
# http://codeforces.com/problemset/problem/111/E
# 475
# http://codeforces.com/problemset/problem/112/A
# 476
# http://codeforces.com/problemset/problem/112/B
# 477
# http://codeforces.com/problemset/problem/112/C
# 478
# http://codeforces.com/problemset/problem/112/D
# ------------------------- written to file problem_texts.tsv
# 479
# http://codeforces.com/problemset/problem/112/E
# 480
# http://codeforces.com/problemset/problem/113/A
# 481
# http://codeforces.com/problemset/problem/113/B
# 482
# http://codeforces.com/problemset/problem/113/C
# 483
# http://codeforces.com/problemset/problem/113/D
# ------------------------- written to file problem_texts.tsv
# 484
# http://codeforces.com/problemset/problem/113/E
# 485
# http://codeforces.com/problemset/problem/114/A
# 486
# http://codeforces.com/problemset/problem/114/B
# 487
# http://codeforces.com/problemset/problem/114/C
# 488
# http://codeforces.com/problemset/problem/114/D
# ------------------------- written to file problem_texts.tsv
# 489
# http://codeforces.com/problemset/problem/114/E
# 490
# http://codeforces.com/problemset/problem/115/A
# 491
# http://codeforces.com/problemset/problem/115/B
# 492
# http://codeforces.com/problemset/problem/115/C
# 493
# http://codeforces.com/problemset/problem/115/D
# ------------------------- written to file problem_texts.tsv
# 494
# http://codeforces.com/problemset/problem/115/E
# 495
# http://codeforces.com/problemset/problem/116/A
# 496
# http://codeforces.com/problemset/problem/116/B
# 497
# http://codeforces.com/problemset/problem/116/C
# 498
# http://codeforces.com/problemset/problem/116/D
# ------------------------- written to file problem_texts.tsv
# 499
# http://codeforces.com/problemset/problem/116/E
# 500
# http://codeforces.com/problemset/problem/117/A
# 501
# http://codeforces.com/problemset/problem/117/B
# 502
# http://codeforces.com/problemset/problem/117/C
# 503
# http://codeforces.com/problemset/problem/117/D
#  Thus
# . Let's consider the first query
# . The second and third positions in the array
#  do not have numbers in the range
# , so the sum obviously equals zero. Let's consider the second query
# . The second and third positions have two numbers that belong to the range
# , their sum equals 5.
# ------------------------- written to file problem_texts.tsv
# 504
# http://codeforces.com/problemset/problem/117/E
# 505
# http://codeforces.com/problemset/problem/118/A
# 506
# http://codeforces.com/problemset/problem/118/B
# 507
# http://codeforces.com/problemset/problem/118/C
# 508
# http://codeforces.com/problemset/problem/118/D
# ------------------------- written to file problem_texts.tsv
# 509
# http://codeforces.com/problemset/problem/118/E
# 510
# http://codeforces.com/problemset/problem/121/A
# 511
# http://codeforces.com/problemset/problem/121/B
# 512
# http://codeforces.com/problemset/problem/121/C
# 513
# http://codeforces.com/problemset/problem/121/D
# ------------------------- written to file problem_texts.tsv
# 514
# http://codeforces.com/problemset/problem/121/E
# 515
# http://codeforces.com/problemset/problem/122/A
# 516
# http://codeforces.com/problemset/problem/122/B
# 517
# http://codeforces.com/problemset/problem/122/C
# 518
# http://codeforces.com/problemset/problem/122/D
# ------------------------- written to file problem_texts.tsv
# 519
# http://codeforces.com/problemset/problem/122/E
# 520
# http://codeforces.com/problemset/problem/123/A
# 521
# http://codeforces.com/problemset/problem/123/B
# 522
# http://codeforces.com/problemset/problem/123/C
# 523
# http://codeforces.com/problemset/problem/123/D
# ------------------------- written to file problem_texts.tsv
# 524
# http://codeforces.com/problemset/problem/123/E
# 525
# http://codeforces.com/problemset/problem/124/A
# 526
# http://codeforces.com/problemset/problem/124/B
# 527
# http://codeforces.com/problemset/problem/124/C
# 528
# http://codeforces.com/problemset/problem/124/D
# ------------------------- written to file problem_texts.tsv
# 529
# http://codeforces.com/problemset/problem/124/E
# 530
# http://codeforces.com/problemset/problem/126/A
# 531
# http://codeforces.com/problemset/problem/126/B
# 532
# http://codeforces.com/problemset/problem/126/C
# 533
# http://codeforces.com/problemset/problem/126/D
# ------------------------- written to file problem_texts.tsv
# 534
# http://codeforces.com/problemset/problem/126/E
# 535
# http://codeforces.com/problemset/problem/127/A

# %% [markdown]
# #  Notes
#
# API information:
# * http://docs.tcapi.apiary.io/#reference/data/top-ranked-srm-members/top-ranked-srm-members
#
# Getting data on users:
# * http://api.topcoder.com/v2/users/yj12/statistics/data/srm
#
# Getting list of users:
# * Note this only goes by 200 at a time
# * http://www.topcoder.com/tc?cc=&sc=&sd=&cc=&module=AlgoRank&nr=5000&sr=4000
