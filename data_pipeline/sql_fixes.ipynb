# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

from sqlalchemy import *
from sqlalchemy_utils import database_exists, create_database
import psycopg2

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 5.0)
plt.rcParams['figure.facecolor'] = 'white'

# %% [markdown]
# 19,307,026 submissions
#
# 5,326,298 contest submissions

# %%
dbname = 'codeforces'
username = 'Joy'
con = psycopg2.connect(database = dbname, user = username)
cur = con.cursor()

# %%
cur.execute("select relname from pg_class where relkind='r' and relname !~ '^(pg_|sql_)';")
print cur.fetchall()
# Out:
# [('handles',), ('problem_info',), ('submissions',), ('contests',), ('hacks',), ('user_rating',), ('problem_rating',), ('tags',)]

# %%
cur.execute("select * from handles")
handles = [c[0] for c in cur.fetchall()]

# %%
query = "select * from submissions limit 10"
pd.read_sql_query(query, con)
# Out:
#     handle        id   language  memoryBytes participanttype  passedtestcount  \
# 0  tourist  27036616  GNU C++11     19763200      CONTESTANT               33
# 1  tourist  27035049  GNU C++11     19763200      CONTESTANT               14
# 2  tourist  27030563  GNU C++11     30208000      CONTESTANT               47
# 3  tourist  27029223  GNU C++11     13004800      CONTESTANT                2
# 4  tourist  27023350  GNU C++11     13107200      CONTESTANT               16
# 5  tourist  27022631  GNU C++11      4915200      CONTESTANT              103
# 6  tourist  27021179  GNU C++11      9932800      CONTESTANT                4
# 7  tourist  27019416  GNU C++11     28979200      CONTESTANT               39
# 8  tourist  27018858  GNU C++11     17920000      CONTESTANT               79
# 9  tourist  27018375  GNU C++11            0      CONTESTANT               93
#
#    points  relativetimeseconds  starttimeseconds  timemilliseconds   testset  \
# 0    3500                 7077        1494523977              1294     TESTS
# 1    3500                 6853        1494523753              2808  PRETESTS
# 2    3250                 4891        1494521791               483     TESTS
# 3    3250                 4346        1494521246                 0  PRETESTS
# 4    2500                 2511        1494519411                78     TESTS
# 5    2000                 2240        1494519140                15     TESTS
# 6    2500                 1719        1494518619              2000  PRETESTS
# 7    1000                 1145        1494518045               389     TESTS
# 8    1500                  979        1494517879                62     TESTS
# 9     500                  834        1494517734                15     TESTS
#
#                verdict contestid problemid problemrating
# 0                   OK       799         G          None
# 1              SKIPPED       799         G          None
# 2                   OK       799         F          None
# 3         WRONG_ANSWER       799         F          None
# 4         WRONG_ANSWER       799         E          None
# 5                   OK       799         D          None
# 6  TIME_LIMIT_EXCEEDED       799         E          None
# 7                   OK       799         B          None
# 8                   OK       799         C          None
# 9                   OK       799         A          None

# %%
query = """
SELECT * FROM submissions WHERE "participantType"='CONTESTANT'
"""
cur.execute(query)
#pd.read_sql_query(query, con)

# %%
cur.rowcount
# Out:
# 5326298

# %% [markdown]
# # rename and re-type columns
# postgreSQL changes all queries to lower case unless in double quotes
# some columns were defined as strings but somehow became integers

# %%
query = """
ALTER TABLE submissions RENAME COLUMN "participantType" TO participanttype;
ALTER TABLE submissions RENAME COLUMN "passedTestCount" TO passedtestcount;
ALTER TABLE submissions RENAME COLUMN "relativeTimeSeconds" TO relativetimeseconds;
ALTER TABLE submissions RENAME COLUMN "startTimeSeconds" TO starttimeseconds;
ALTER TABLE submissions RENAME COLUMN "timeMilliseconds" TO timemilliseconds;
ALTER TABLE submissions RENAME COLUMN "contestID" TO contestid;
ALTER TABLE submissions RENAME COLUMN "problemID" TO problemid;
ALTER TABLE submissions RENAME COLUMN "problemRating" TO problemrating;
"""
cur.execute(query)
con.commit()

# %%
query = """
ALTER TABLE submissions DROP COLUMN IF EXISTS problemrating
"""
cur.execute(query)
con.commit()

# %%
query = """
ALTER TABLE problem_rating RENAME COLUMN "contestID" TO contestid;
ALTER TABLE problem_rating RENAME COLUMN "problemID" TO problemid;
ALTER TABLE problem_rating RENAME COLUMN "problemRating" TO problemrating;
"""
cur.execute(query)
con.commit()

# %%
query = """
ALTER TABLE problem_rating ALTER COLUMN contestid TYPE text;
ALTER TABLE problem_info ALTER COLUMN contestid TYPE text;
"""
cur.execute(query)
con.commit()

# %%
query = """
ALTER TABLE tags ALTER COLUMN contestid TYPE text;
ALTER TABLE tags ALTER COLUMN problemid TYPE text;
"""
cur.execute(query)
con.commit()

# %%
query = """
ALTER TABLE contests RENAME COLUMN "durationSeconds" TO durationseconds;
ALTER TABLE contests RENAME COLUMN "relativeTimeSeconds" TO relativetimeseconds;
ALTER TABLE contests RENAME COLUMN "startTimeSeconds" TO starttimeseconds;
ALTER TABLE hacks RENAME COLUMN "creationTimeSeconds" TO creationtimeseconds;
ALTER TABLE hacks RENAME COLUMN "contestID" TO contestid;
ALTER TABLE hacks RENAME COLUMN "problemID" TO problemid;
ALTER TABLE hacks RENAME COLUMN "problemName" TO problemname;
"""
cur.execute(query)
con.commit()

# %%
con.rollback()
query="ALTER TABLE contests RENAME COLUMN id TO contestid;"
cur.execute(query)
con.commit()

# %%
con.rollback()
query="ALTER TABLE hacks RENAME COLUMN id TO hackid;"
cur.execute(query)
con.commit()

# %%
con.rollback()
query="ALTER TABLE submissions RENAME COLUMN id TO submissionid;"
cur.execute(query)
con.commit()

# %%
con.rollback()

# %% [markdown]
# # Remove duplicate rows
# Some tables (submissions) have duplicated rows, need to remove this to set a primary key
#
# More on ctids here: https://www.postgresql.org/docs/8.2/static/ddl-system-columns.html
#
# **ctid**
# The physical location of the row version within its table. Note that although the ctid can be used to locate the row version very quickly, a row's ctid will change each time it is updated or moved by VACUUM FULL. Therefore ctid is useless as a long-term row identifier. The OID, or even better a user-defined serial number, should be used to identify logical rows.

# %%
con.rollback()
query = """
DELETE FROM submissions a USING (
      SELECT MIN(ctid) as ctid, submissionid
        FROM submissions 
        GROUP BY submissionid HAVING COUNT(*) > 1
      ) b
      WHERE a.submissionid = b.submissionid 
      AND a.ctid <> b.ctid
"""
cur.execute(query)
con.commit()

# %%
#	contestid	contestname	handle	newrating	oldrating	rank	ratingupdatetimeseconds
#0	785	Codeforces Round #404 (Div. 2)	tasneemria	1352	1327	1928	1489598100
#1	785	Codeforces Round #404 (Div. 2)	tasneemria	1352	1327	1928	1489598100
query = """
DELETE FROM user_rating a USING (
      SELECT MIN(ctid) as ctid, contestid, handle, ratingupdatetimeseconds
        FROM user_rating
        GROUP BY (contestid, handle, ratingupdatetimeseconds) HAVING COUNT(*) > 1
      ) b
      WHERE 
          a.contestid = b.contestid AND
          a.handle = b.handle AND
          a.ratingupdatetimeseconds = b.ratingupdatetimeseconds 
      AND a.ctid <> b.ctid
"""
cur.execute(query)
con.commit()

# %% [markdown]
# # Adding primary keys
# https://www.postgresql.org/docs/9.2/static/ddl-constraints.html
#
# This creates B-trees based on the primary keys
#
# Examples:
#
# http://www.postgresqltutorial.com/postgresql-foreign-key/
#
# Tables:
# * handles
# * problem_info
# * submissions
# * contests
# * hacks
# * user_rating
# * problem_rating
# * tags

# %%
con.rollback()
query = """
ALTER TABLE handles ADD PRIMARY KEY (handle);
"""
cur.execute(query)
con.commit()

# %%
query = """
ALTER TABLE contests ADD PRIMARY KEY (contestid);
ALTER TABLE hacks DROP CONSTRAINT hacks_pkey;
ALTER TABLE hacks ADD PRIMARY KEY (hackid, verdict, defender, hacker, contestid, problemid);
ALTER TABLE problem_info ADD PRIMARY KEY (contestid, problemid, division);
ALTER TABLE problem_rating ADD PRIMARY KEY (contestid, problemid);
ALTER TABLE submissions ADD PRIMARY KEY (handle, contestid, problemid, participanttype, verdict, submissionid, starttimeseconds);
ALTER TABLE tags ADD PRIMARY KEY (contestid, problemid, tag);
ALTER TABLE user_rating ADD PRIMARY KEY (contestid, handle);
"""
cur.execute(query)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-16-8a30468aaef5> in <module>()
#       9 ALTER TABLE user_rating ADD PRIMARY KEY (contestid, handle);
#      10 """
# ---> 11 cur.execute(query)
#
# ProgrammingError: multiple primary keys for table "contests" are not allowed

# %%
con.commit()

# %%
con.rollback()
query = """
SELECT * FROM user_rating  WHERE contestid=785 AND handle='tasneemria';
"""
pd.read_sql(query, con)
# Out:
#    contestid                     contestname      handle  newrating  \
# 0        785  Codeforces Round #404 (Div. 2)  tasneemria       1352
#
#    oldrating  rank  ratingupdatetimeseconds
# 0       1327  1928               1489598100

# %%
con.rollback()
query = """
SELECT * FROM submissions WHERE
    handle='zhanyl' AND
    contestid='100186' AND
    problemid='L' AND
    participanttype='VIRTUAL' AND
    verdict='OK' AND
    submissionid=7254239 AND
    starttimeseconds=1406433825
"""
cur.execute(query)
pd.read_sql_query(query, con)
#con.commit()
# Out:
#    handle  submissionid language  memoryBytes participanttype  \
# 0  zhanyl       7254239  GNU C++       204800         VIRTUAL
#
#    passedtestcount  points  relativetimeseconds  starttimeseconds  \
# 0               20       0                  225        1406433825
#
#    timemilliseconds testset verdict contestid problemid
# 0                60   TESTS      OK    100186         L

# %% [markdown]
# # Exploratory analysis

# %%
query = """
SELECT * FROM submissions 
    INNER JOIN problem_rating 
        USING
        (
            problemid,
            contestid
        )
     WHERE handle='tourist'
"""
     #order by starttimeseconds, submissions.contestid, submissions.problemid
df_user = pd.read_sql_query(query, con)

# %%
query = """
SELECT * FROM user_rating
"""
df_rating = pd.read_sql_query(query, con)

# %%
df_rating.head()
# Out:
#    contestid                     contestname    handle  newrating  oldrating  \
# 0        168  Codeforces Round #114 (Div. 2)  Shoutmon       1209       1255
# 1        205  Codeforces Round #129 (Div. 2)  Shoutmon       1315       1209
# 2        208  Codeforces Round #130 (Div. 2)  Shoutmon       1257       1315
# 3        215  Codeforces Round #132 (Div. 2)  Shoutmon       1404       1257
# 4        216  Codeforces Round #133 (Div. 2)  Shoutmon       1532       1404
#
#    rank  ratingupdatetimeseconds
# 0   944               1332867600
# 1   475               1342027800
# 2  1091               1343065200
# 3   388               1344274200
# 4   241               1344965400

# %%
df_user
# Out:
#      problemid contestid   handle        id   language  memoryBytes  \
# 0            A         2  tourist      7267     Delphi       307200
# 1            A         2  tourist      7331     Delphi       307200
# 2            B         2  tourist      7421     Delphi     16691200
# 3            B         2  tourist      7476     Delphi     16691200
# 4            B         2  tourist      7531     Delphi     16691200
# 5            C         2  tourist      7848     Delphi       409600
# 6            C         2  tourist      7874     Delphi       409600
# 7            C         2  tourist      7913     Delphi       409600
# 8            C         2  tourist      7962     Delphi       409600
# 9            C         2  tourist      7983     Delphi       409600
# 10           C         2  tourist      7994     Delphi       409600
# 11           C         5  tourist     24745     Delphi      7884800
# 12           A        10  tourist     43119     Delphi       819200
# 13           B        10  tourist     43251     Delphi      6348800
# 14           C        10  tourist     43384     Delphi       819200
# 15           E        10  tourist     44404     Delphi       819200
# 16           E        10  tourist     44542     Delphi       819200
# 17           E        10  tourist     44792     Delphi       819200
# 18           E        10  tourist     44903     Delphi       819200
# 19           E        10  tourist     44982     Delphi       819200
# 20           E        10  tourist     45138     Delphi       819200
# 21           E        10  tourist     45183     Delphi       819200
# 22           E        10  tourist     45198     Delphi       819200
# 23           E        10  tourist     45212     Delphi       819200
# 24           E        10  tourist     45247     Delphi       819200
# 25           E        10  tourist     45251     Delphi       819200
# 26           E        10  tourist     45266     Delphi       819200
# 27           E        10  tourist     45293     Delphi       819200
# 28           E        10  tourist     45295     Delphi       819200
# 29           E        10  tourist     45304     Delphi       819200
# ...        ...       ...      ...       ...        ...          ...
# 1075         G       776  tourist  24933167  GNU C++11      5734400
# 1076         G       776  tourist  24933167  GNU C++11      5734400
# 1077         F       776  tourist  24937179  GNU C++11     79257600
# 1078         F       776  tourist  24937179  GNU C++11     79257600
# 1079         F       776  tourist  24937635  GNU C++11     88371200
# 1080         F       776  tourist  24937635  GNU C++11     88371200
# 1081         F       776  tourist  24940601  GNU C++11     99225600
# 1082         F       776  tourist  24940601  GNU C++11     99225600
# 1083         C       799  tourist  27017541  GNU C++11     16076800
# 1084         C       799  tourist  27017541  GNU C++11     16076800
# 1085         A       799  tourist  27018375  GNU C++11            0
# 1086         A       799  tourist  27018375  GNU C++11            0
# 1087         C       799  tourist  27018858  GNU C++11     17920000
# 1088         C       799  tourist  27018858  GNU C++11     17920000
# 1089         B       799  tourist  27019416  GNU C++11     28979200
# 1090         B       799  tourist  27019416  GNU C++11     28979200
# 1091         E       799  tourist  27021179  GNU C++11      9932800
# 1092         E       799  tourist  27021179  GNU C++11      9932800
# 1093         D       799  tourist  27022631  GNU C++11      4915200
# 1094         D       799  tourist  27022631  GNU C++11      4915200
# 1095         E       799  tourist  27023350  GNU C++11     13107200
# 1096         E       799  tourist  27023350  GNU C++11     13107200
# 1097         F       799  tourist  27029223  GNU C++11     13004800
# 1098         F       799  tourist  27029223  GNU C++11     13004800
# 1099         F       799  tourist  27030563  GNU C++11     30208000
# 1100         F       799  tourist  27030563  GNU C++11     30208000
# 1101         G       799  tourist  27035049  GNU C++11     19763200
# 1102         G       799  tourist  27035049  GNU C++11     19763200
# 1103         G       799  tourist  27036616  GNU C++11     19763200
# 1104         G       799  tourist  27036616  GNU C++11     19763200
#
#      participanttype  passedtestcount  points  relativetimeseconds  \
# 0         CONTESTANT                9       0                  473
# 1         CONTESTANT               20       0                  814
# 2         CONTESTANT               30       0                 1406
# 3         CONTESTANT               34       0                 1701
# 4         CONTESTANT               37       0                 2168
# 5         CONTESTANT                1       0                 5218
# 6         CONTESTANT                1       0                 5436
# 7         CONTESTANT                9       0                 5811
# 8         CONTESTANT                9       0                 6386
# 9         CONTESTANT                9       0                 6524
# 10        CONTESTANT                9       0                 6648
# 11          PRACTICE               43       0               508921
# 12        CONTESTANT               30       0                  169
# 13        CONTESTANT               40       0                  611
# 14        CONTESTANT               40       0                  912
# 15        CONTESTANT                2       0                 4170
# 16        CONTESTANT                4       0                 4797
# 17        CONTESTANT                4       0                 5969
# 18        CONTESTANT               29       0                 6471
# 19        CONTESTANT               22       0                 6721
# 20        CONTESTANT               12       0                 7089
# 21        CONTESTANT               88       0                 7168
# 22        CONTESTANT               29       0                 7188
# 23        CONTESTANT               29       0                 7197
# 24          PRACTICE               88       0                 7580
# 25          PRACTICE               88       0                 7604
# 26          PRACTICE               88       0                 7729
# 27          PRACTICE               88       0                 7944
# 28          PRACTICE               88       0                 7967
# 29          PRACTICE               88       0                 8000
# ...              ...              ...     ...                  ...
# 1075      CONTESTANT               70    3250                 3858
# 1076      CONTESTANT               70    3250                 3858
# 1077      CONTESTANT                2    3000                 6132
# 1078      CONTESTANT                2    3000                 6132
# 1079      CONTESTANT                5    3000                 6275
# 1080      CONTESTANT                5    3000                 6275
# 1081      CONTESTANT               66    3000                 7389
# 1082      CONTESTANT               66    3000                 7389
# 1083      CONTESTANT                3    1500                  594
# 1084      CONTESTANT                3    1500                  594
# 1085      CONTESTANT               93     500                  834
# 1086      CONTESTANT               93     500                  834
# 1087      CONTESTANT               79    1500                  979
# 1088      CONTESTANT               79    1500                  979
# 1089      CONTESTANT               39    1000                 1145
# 1090      CONTESTANT               39    1000                 1145
# 1091      CONTESTANT                4    2500                 1719
# 1092      CONTESTANT                4    2500                 1719
# 1093      CONTESTANT              103    2000                 2240
# 1094      CONTESTANT              103    2000                 2240
# 1095      CONTESTANT               16    2500                 2511
# 1096      CONTESTANT               16    2500                 2511
# 1097      CONTESTANT                2    3250                 4346
# 1098      CONTESTANT                2    3250                 4346
# 1099      CONTESTANT               47    3250                 4891
# 1100      CONTESTANT               47    3250                 4891
# 1101      CONTESTANT               14    3500                 6853
# 1102      CONTESTANT               14    3500                 6853
# 1103      CONTESTANT               33    3500                 7077
# 1104      CONTESTANT               33    3500                 7077
#
#       starttimeseconds  timemilliseconds   testset              verdict  \
# 0           1267117673                10     TESTS         WRONG_ANSWER
# 1           1267118014                30     TESTS                   OK
# 2           1267118606              5000     TESTS  TIME_LIMIT_EXCEEDED
# 3           1267118901               380     TESTS         WRONG_ANSWER
# 4           1267119368               330     TESTS                   OK
# 5           1267122418                10     TESTS         WRONG_ANSWER
# 6           1267122636                10     TESTS         WRONG_ANSWER
# 7           1267123011                30     TESTS        RUNTIME_ERROR
# 8           1267123586                10     TESTS        RUNTIME_ERROR
# 9           1267123724                10     TESTS        RUNTIME_ERROR
# 10          1267123848                30     TESTS        RUNTIME_ERROR
# 11          1269609721               160     TESTS                   OK
# 12          1271346469                30     TESTS                   OK
# 13          1271346911                90     TESTS                   OK
# 14          1271347212                50     TESTS                   OK
# 15          1271350470                30     TESTS         WRONG_ANSWER
# 16          1271351097                30     TESTS         WRONG_ANSWER
# 17          1271352269                30     TESTS         WRONG_ANSWER
# 18          1271352771                30     TESTS         WRONG_ANSWER
# 19          1271353021                30     TESTS         WRONG_ANSWER
# 20          1271353389                90     TESTS         WRONG_ANSWER
# 21          1271353468              1440     TESTS         WRONG_ANSWER
# 22          1271353488                30     TESTS         WRONG_ANSWER
# 23          1271353497                30     TESTS         WRONG_ANSWER
# 24          1271353880              1860     TESTS         WRONG_ANSWER
# 25          1271353904              1860     TESTS         WRONG_ANSWER
# 26          1271354029               920     TESTS        RUNTIME_ERROR
# 27          1271354244              2000     TESTS  TIME_LIMIT_EXCEEDED
# 28          1271354267              2000     TESTS  TIME_LIMIT_EXCEEDED
# 29          1271354300              2000     TESTS  TIME_LIMIT_EXCEEDED
# ...                ...               ...       ...                  ...
# 1075        1487864958               358     TESTS                   OK
# 1076        1487864958               358     TESTS                   OK
# 1077        1487867232                31  PRETESTS         WRONG_ANSWER
# 1078        1487867232                31  PRETESTS         WRONG_ANSWER
# 1079        1487867375               124  PRETESTS         WRONG_ANSWER
# 1080        1487867375               124  PRETESTS         WRONG_ANSWER
# 1081        1487868489               264     TESTS                   OK
# 1082        1487868489               264     TESTS                   OK
# 1083        1494517494                 0  PRETESTS         WRONG_ANSWER
# 1084        1494517494                 0  PRETESTS         WRONG_ANSWER
# 1085        1494517734                15     TESTS                   OK
# 1086        1494517734                15     TESTS                   OK
# 1087        1494517879                62     TESTS                   OK
# 1088        1494517879                62     TESTS                   OK
# 1089        1494518045               389     TESTS                   OK
# 1090        1494518045               389     TESTS                   OK
# 1091        1494518619              2000  PRETESTS  TIME_LIMIT_EXCEEDED
# 1092        1494518619              2000  PRETESTS  TIME_LIMIT_EXCEEDED
# 1093        1494519140                15     TESTS                   OK
# 1094        1494519140                15     TESTS                   OK
# 1095        1494519411                78     TESTS         WRONG_ANSWER
# 1096        1494519411                78     TESTS         WRONG_ANSWER
# 1097        1494521246                 0  PRETESTS         WRONG_ANSWER
# 1098        1494521246                 0  PRETESTS         WRONG_ANSWER
# 1099        1494521791               483     TESTS                   OK
# 1100        1494521791               483     TESTS                   OK
# 1101        1494523753              2808  PRETESTS              SKIPPED
# 1102        1494523753              2808  PRETESTS              SKIPPED
# 1103        1494523977              1294     TESTS                   OK
# 1104        1494523977              1294     TESTS                   OK
#
#       problemrating
# 0              1291
# 1              1291
# 2              1621
# 3              1621
# 4              1621
# 5              2019
# 6              2019
# 7              2019
# 8              2019
# 9              2019
# 10             2019
# 11             1580
# 12             1010
# 13             1407
# 14             1653
# 15             2225
# 16             2225
# 17             2225
# 18             2225
# 19             2225
# 20             2225
# 21             2225
# 22             2225
# 23             2225
# 24             2225
# 25             2225
# 26             2225
# 27             2225
# 28             2225
# 29             2225
# ...             ...
# 1075           2817
# 1076           2817
# 1077           2752
# 1078           2752
# 1079           2752
# 1080           2752
# 1081           2752
# 1082           2752
# 1083           1786
# 1084           1786
# 1085           1230
# 1086           1230
# 1087           1786
# 1088           1786
# 1089           1409
# 1090           1409
# 1091           2579
# 1092           2579
# 1093           2126
# 1094           2126
# 1095           2579
# 1096           2579
# 1097           3347
# 1098           3347
# 1099           3347
# 1100           3347
# 1101           3642
# 1102           3642
# 1103           3642
# 1104           3642
#
# [1105 rows x 15 columns]

# %%
groups = df_user.groupby(['contestid', 'problemid'])
for k, v in groups:
    print k
    df = v
    break
# Out:
# ('1', 'A')

# %% [markdown]
# # ideas
# Get last 10 solved problems before each contest
#
# **features**
# - average time of solves before contest
# - mean, var, max # wrong tries on problems
# - mean, var of amt time between solves
# - mean, var of difference between rating and problem rating
# - total # problems solved
# - \# problems solved where rating > x
# - tags??
# - contest vs practice questions
#
#
# **Knowledge graph**
#
# distribution of accuracy by tags (and problem rating?) by group of users of a certain rating
#
# Can look at difference in this distribution between low and high users
#
#
# **NLP**
#
# Look at contest posts to see how much users liked a contest
#
# predict problem tags from problem texts --> can apply to other websites
# - trivial examples will include things like "tree" --> graph
#
#
# ** null model **
# linear regression on difference, assume always the same

# %%
df = groups.get_group(('97', 'D'))
df.sort_values('starttimeseconds')
# Out:
#     problemid contestid   handle      id language  memoryBytes  \
# 237         D        97  tourist  547491   Delphi      3174400
# 238         D        97  tourist  547756   Delphi      3072000
# 239         D        97  tourist  547758   Delphi      6451200
# 240         D        97  tourist  547775  GNU C++      6348800
# 241         D        97  tourist  547776   Delphi      3174400
# 242         D        97  tourist  547778   Delphi      3174400
# 243         D        97  tourist  547780   Delphi      3174400
# 244         D        97  tourist  547781   Delphi      3174400
# 245         D        97  tourist  547783   Delphi      3174400
# 246         D        97  tourist  547787   Delphi      2867200
# 247         D        97  tourist  547789   Delphi      2764800
# 248         D        97  tourist  547794   Delphi      2764800
# 249         D        97  tourist  547799   Delphi      2764800
# 250         D        97  tourist  547840   Delphi      1740800
# 251         D        97  tourist  547844   Delphi      1945600
#
#     participanttype  passedtestcount  points  relativetimeseconds  \
# 237      CONTESTANT               71    2000                 7175
# 238        PRACTICE                0    2000                20259
# 239        PRACTICE               53    2000                20290
# 240        PRACTICE               53    2000                20578
# 241        PRACTICE               71    2000                20605
# 242        PRACTICE               71    2000                20639
# 243        PRACTICE               70    2000                20666
# 244        PRACTICE               70    2000                20690
# 245        PRACTICE               71    2000                20710
# 246        PRACTICE               70    2000                20795
# 247        PRACTICE               71    2000                20841
# 248        PRACTICE                0    2000                20934
# 249        PRACTICE               72    2000                21069
# 250        PRACTICE                8    2000                23027
# 251        PRACTICE                8    2000                23104
#
#      starttimeseconds  timemilliseconds testset              verdict  \
# 237        1310738375              4000   TESTS  TIME_LIMIT_EXCEEDED
# 238        1310751459                10   TESTS        RUNTIME_ERROR
# 239        1310751490              4000   TESTS  TIME_LIMIT_EXCEEDED
# 240        1310751778              4000   TESTS  TIME_LIMIT_EXCEEDED
# 241        1310751805              4000   TESTS  TIME_LIMIT_EXCEEDED
# 242        1310751839              4000   TESTS  TIME_LIMIT_EXCEEDED
# 243        1310751866              4000   TESTS  TIME_LIMIT_EXCEEDED
# 244        1310751890              4000   TESTS  TIME_LIMIT_EXCEEDED
# 245        1310751910              4000   TESTS  TIME_LIMIT_EXCEEDED
# 246        1310751995              4000   TESTS  TIME_LIMIT_EXCEEDED
# 247        1310752041              4000   TESTS  TIME_LIMIT_EXCEEDED
# 248        1310752134                10   TESTS         WRONG_ANSWER
# 249        1310752269              2670   TESTS                   OK
# 250        1310754227              4000   TESTS  TIME_LIMIT_EXCEEDED
# 251        1310754304              4000   TESTS  TIME_LIMIT_EXCEEDED
#
#      problemrating
# 237           2682
# 238           2682
# 239           2682
# 240           2682
# 241           2682
# 242           2682
# 243           2682
# 244           2682
# 245           2682
# 246           2682
# 247           2682
# 248           2682
# 249           2682
# 250           2682
# 251           2682
