# %% [markdown]
# # OLS with better features

# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import scipy
import psycopg2
import feature_functions as ff
con = psycopg2.connect(database='codeforces', user='Joy')
cur = con.cursor()
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 10.0)
plt.rcParams['figure.facecolor'] = 'white'

# %% [markdown]
# * cluster all programming languages
# * cluster tags
# * Time lagged variables
# * follow similar processing as in RNN
# * bayesian inference of how unlikely last contest results were
# * can look at tags of problems solved via probabilistic programming https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers

# %%
with open('rnn_train/tourist.csv') as f:
    correct_columns = [l.strip() for l in f.readline().split(',')]

# %%
pd.read_sql("select * from submissions WHERE handle='chenmark' AND contestid='497' AND problemid='A'", con)
# Out:
#      handle  submissionid language  memoryBytes participanttype  \
# 0  chenmark       9164431  GNU C++       204800      CONTESTANT
#
#    passedtestcount  points  relativetimeseconds  starttimeseconds  \
# 0               49     750                  535        1418834335
#
#    timemilliseconds testset verdict contestid problemid
# 0                31   TESTS      OK       497         A

# %%
reload(ff)
binvars = ff.get_categorical_variables([
    'all_tags',
    'all_verdicts',
    'all_language'
])  
df = ff.get_features('chenmark', binvars, correct_columns)

list(df.columns)
# Out:
# nan
# Empty DataFrame
# Columns: [contestid, problemid, starttimeseconds, stoptimeseconds]
# Index: []
# 2.14694444444
#    contestid problemid  starttimeseconds  stoptimeseconds
# 0        358         A        1382717475       1382725204
# 99.4941666667
#    contestid problemid  starttimeseconds  stoptimeseconds
# 4        361         C        1384107851       1384466030
# 99.4941666667
#    contestid problemid  starttimeseconds  stoptimeseconds
# 4        361         C        1384107851       1384466030
# 99.4941666667
#    contestid problemid  starttimeseconds  stoptimeseconds
# 4        361         C        1384107851       1384466030
# 99.4941666667
#    contestid problemid  starttimeseconds  stoptimeseconds
# 4        361         C        1384107851       1384466030
# 7674.68583333
#     contestid problemid  starttimeseconds  stoptimeseconds
# 26        373         C        1387327840       1414956709
# 7674.68583333
#     contestid problemid  starttimeseconds  stoptimeseconds
# ...

# %%
test = pd.read_csv('rnn_train/chenmark.csv')
test['dp']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# Name: dp, dtype: float64
